# %% [markdown]
# # Лабораторна робота 3
#
# ## Завдання
#
#
# <ol>
#   <li>Створити команду у складі принаймні 3 учасники.</li>
#   <li>На основі підготовлених у попередній лабораторній роботі речень кожного з учасників створити загальний набір даних розмірністю (100, n), де n -кількість учасників команди, та відповідні мітки класів до них</li>
#   <li>Здійснити підготовку набору даних до моделювання (tokenization&embedding, train_test_split)</li>
#   <li>Вирішити завдання мультикласової класифікації на створеному наборі даних із використанням методів: Naive Bayes  Model, Dense Neural Network</li>
#   <li>Здійснити порівняння ефективності моделей</li>
#   <li>Відповіді оформити .ipynb, .csv документами</li>
#   <li>Викласти у зазначений репозіторій GitHub в окремій папці з назвою Lab3 де мають бути .ipynb файл та необхідні файли з даними</li>
#   <li>Підготуватися до захисту та доповіді результатів (1 доповідь від команди)</li>
# </ol>
