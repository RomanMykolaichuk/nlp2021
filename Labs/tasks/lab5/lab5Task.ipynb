# %% [markdown]
# # Лабораторна робота 5
#
# ## Завдання
#
#
# <ol>
#   <li>Робота проводиться на основі вихідних даних та у складі команд попередньої лабораторної роботи</li>
#   <li>Вирішити завдання мультикласової класифікації на створеному наборі даних із використанням методів transfer learning (universal sentence encoder, universal sentence encoder + fine-tuning + google colab)</li>
#   <li>Здійснити порівняння ефективності моделей</li>
#   <li>Відповіді оформити .ipynb, .csv документами, із зазначенням посилання для виконання на google colab</li>
#   <li>Викласти у зазначений репозіторій GitHub в окремій папці з назвою Lab5 де мають бути .ipynb файл та необхідні файли з даними</li>
#   <li>Підготуватися до захисту та доповіді результатів (1 доповідь від команди)</li>
# </ol>
